# %%
# %reload_ext jumper_extension
# Out:
# [JUmPER]: ADLXPybind not available. AMD GPU monitoring disabled.
# /data/cat/ws/s4122485-jumpllm_test/jumper_jupyter_performance/jumper_extension/monitor/metrics/gpu/nvml.py:54: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml
# [JUmPER]: Perfmonitor extension loaded

# %%
# %reload_ext bali
# Out:
# INFO 05-13 16:53:31 [__init__.py:239] Automatically detected platform cuda.
# WARNING:root:Acceleration framework 'deepspeed' unavailable and will be skipped (No module named 'mii')
# BALI extension loaded.

# %%
#%perfmonitor_stop

# %%
# %perfmonitor_start --monitor thread_bali
# Out:
# [JUmPER]: ADLXPybind not available. AMD GPU monitoring disabled.
# WARNING:extension:[JUmPER]: ADLXPybind not available. AMD GPU monitoring disabled.
# [JUmPER]: Performance monitoring started (PID: 1564766, Interval: 1.0s)
# INFO:extension:[JUmPER]: Performance monitoring started (PID: 1564766, Interval: 1.0s)

# %%
# %%bali_config
# model_name: facebook/opt-1.3b
# frameworks: hf_accelerate
# batch_size: 128 256
# input_len: 32
# output_len: 32
# warm_up_reps: 0
# repeats: 1
# Out:
# Configuration updated!

# %%
# %bali_config_show
# Out:
# BALI Configuration:
# model_name: facebook/opt-1.3b
# data: /data/cat/ws/s4122485-jumpllm_test/BALI/pyenv_inferbench_cuda126_torch260/lib64/python3.9/site-packages/bali/data/prompts.txt
# frameworks: hf_accelerate
# repeats: 1
# warm_up_reps: 0
# batch_size: 128 256
# num_samples: 1024
# num_gpus: 1
# input_len: 32
# output_len: 32
# generate_from_token: True
# dtype: float16
# tokenizer_init_config: {'padding': 'max_length', 'padding_side': 'left', 'truncation': 'only_first'}
# tokenize_config: {'return_tensors': 'pt', 'padding': 'max_length', 'truncation': True}
# generation_config: {'do_sample': True, 'max_token': 100, 'max_new_tokens': 100}
# output_dir:
# save_slurm_config: False
# config_file: config.json
# compression_config: {'model': '', 'rate': 0.5}

# %%
# %bali_run
# Out:
# 2026-05-13 16:54:17,172 - INFO - Logging in to Huggingface Hub
# Running 2 combinations -> bali_results/1564766/1
# [1/2] facebook/opt-1.3b | hf_accelerate | bs=128 | 32→32
# Benchmark config:
#  {'model_name': 'facebook/opt-1.3b', 'tokenizer': None, 'frameworks': ['hf_accelerate'], 'data': '/data/cat/ws/s4122485-jumpllm_test/BALI/pyenv_inferbench_cuda126_torch260/lib64/python3.9/site-packages/bali/data/prompts.txt', 'output_dir': 'bali_results/1564766/1/facebook_opt-1.3b/hf_accelerate/128/32/32', 'config_file': '/tmp/tmpiia93oq4.json', 'save_slurm_config': False, 'loglevel': 'info', 'input_len': 32, 'output_len': 32, 'dtype': 'float16', 'warm_up_reps': 0, 'repeats': 1, 'num_gpus': 1, 'batch_size': 128, 'generate_from_token': True, 'num_samples': 1024, 'tokenizer_init_config': {'padding': 'max_length', 'padding_side': 'left', 'truncation': 'only_first'}, 'tokenize_config': {'return_tensors': 'pt', 'padding': 'max_length', 'truncation': True}, 'compression_config': {'model': '', 'rate': 0.5}, 'hf_login_token': None, 'generation_config': {'do_sample': True, 'max_token': 100, 'max_new_tokens': 100}}
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# 2026-05-13 16:54:17,179 - INFO - Starting Benchmark...
# 2026-05-13 16:54:17,181 - INFO - Saved configs to bali_results/1564766/1/facebook_opt-1.3b/hf_accelerate/128/32/32/config.json
# Framework:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-05-13 16:54:17,188 - INFO - Running acceleration framework hf_accelerate…
# Warm Up: 0it [00:00, ?it/s]
# 2026-05-13 16:54:17,191 - INFO - Starting actual benchmark...
# Repeat:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-05-13 16:54:18,781 - INFO - Input IDs shape per batch:torch.Size([128, 32])
# batch:   0%|          | 0/8 [00:00<?, ?it/s]
# 2026-05-13 16:54:25,952 - INFO - total time to run Benchmark hf_accelerate: 8.747735053068027s
# 2026-05-13 16:54:25,953 - INFO - Memory allocated before clearing cache: 34078720 bytes
# 2026-05-13 16:54:26,172 - INFO - Memory allocated after clearing cache: 33554432 bytes
# 2026-05-13 16:54:26,179 - INFO - RESULTS
# ╒═══════════════╤══════════════════╤═══════════════════════╤═════════════════════╤═══════════════════╤══════════════════╤═════════════════════╕
# │ framework     │   total_time_avg │   generation_time_avg │   token_per_sec_avg │   sequences/s_avg │   setup_time_avg │   tokenize_time_avg │
# ╞═══════════════╪══════════════════╪═══════════════════════╪═════════════════════╪═══════════════════╪══════════════════╪═════════════════════╡
# │ hf_accelerate │          8.74774 │               7.16385 │             4387.03 │           137.095 │          1.27845 │             0.30544 │
# ╘═══════════════╧══════════════════╧═══════════════════════╧═════════════════════╧═══════════════════╧══════════════════╧═════════════════════╛
# 2026-05-13 16:54:26,183 - INFO - Saved Benchmark summary to bali_results/1564766/1/facebook_opt-1.3b/hf_accelerate/128/32/32/benchmark_summary.csv
# 2026-05-13 16:54:26,203 - INFO - Logging in to Huggingface Hub
# Saved results to bali_results/1564766/1/facebook_opt-1.3b/hf_accelerate/128/32/32/benchmark_results.json
# ✓
# [2/2] facebook/opt-1.3b | hf_accelerate | bs=256 | 32→32
# Benchmark config:
#  {'model_name': 'facebook/opt-1.3b', 'tokenizer': None, 'frameworks': ['hf_accelerate'], 'data': '/data/cat/ws/s4122485-jumpllm_test/BALI/pyenv_inferbench_cuda126_torch260/lib64/python3.9/site-packages/bali/data/prompts.txt', 'output_dir': 'bali_results/1564766/1/facebook_opt-1.3b/hf_accelerate/256/32/32', 'config_file': '/tmp/tmppzq4la7l.json', 'save_slurm_config': False, 'loglevel': 'info', 'input_len': 32, 'output_len': 32, 'dtype': 'float16', 'warm_up_reps': 0, 'repeats': 1, 'num_gpus': 1, 'batch_size': 256, 'generate_from_token': True, 'num_samples': 1024, 'tokenizer_init_config': {'padding': 'max_length', 'padding_side': 'left', 'truncation': 'only_first'}, 'tokenize_config': {'return_tensors': 'pt', 'padding': 'max_length', 'truncation': True}, 'compression_config': {'model': '', 'rate': 0.5}, 'hf_login_token': None, 'generation_config': {'do_sample': True, 'max_token': 100, 'max_new_tokens': 100}}
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# 2026-05-13 16:54:26,211 - INFO - Starting Benchmark...
# 2026-05-13 16:54:26,215 - INFO - Saved configs to bali_results/1564766/1/facebook_opt-1.3b/hf_accelerate/256/32/32/config.json
# Framework:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-05-13 16:54:26,221 - INFO - Running acceleration framework hf_accelerate…
# Warm Up: 0it [00:00, ?it/s]
# 2026-05-13 16:54:26,228 - INFO - Starting actual benchmark...
# Repeat:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-05-13 16:54:27,849 - INFO - Input IDs shape per batch:torch.Size([256, 32])
# batch:   0%|          | 0/4 [00:00<?, ?it/s]
# 2026-05-13 16:54:33,738 - INFO - total time to run Benchmark hf_accelerate: 7.495608050026931s
# 2026-05-13 16:54:33,739 - INFO - Memory allocated before clearing cache: 34078720 bytes
# 2026-05-13 16:54:33,961 - INFO - Memory allocated after clearing cache: 33554432 bytes
# 2026-05-13 16:54:33,967 - INFO - RESULTS
# ╒═══════════════╤══════════════════╤═══════════════════════╤═════════════════════╤═══════════════════╤══════════════════╤═════════════════════╕
# │ framework     │   total_time_avg │   generation_time_avg │   token_per_sec_avg │   sequences/s_avg │   setup_time_avg │   tokenize_time_avg │
# ╞═══════════════╪══════════════════╪═══════════════════════╪═════════════════════╪═══════════════════╪══════════════════╪═════════════════════╡
# │ hf_accelerate │          7.49561 │               5.88195 │              5310.3 │           165.947 │          1.32496 │            0.288692 │
# ╘═══════════════╧══════════════════╧═══════════════════════╧═════════════════════╧═══════════════════╧══════════════════╧═════════════════════╛
# 2026-05-13 16:54:33,971 - INFO - Saved Benchmark summary to bali_results/1564766/1/facebook_opt-1.3b/hf_accelerate/256/32/32/benchmark_summary.csv
# Saved results to bali_results/1564766/1/facebook_opt-1.3b/hf_accelerate/256/32/32/benchmark_results.json
# ✓
# Completed! Results: bali_results/1564766/1

# %%
# %bali_plot

# %%
# %matplotlib ipympl

# %%
# %perfmonitor_plot --backend matplotlib
# Out:
# VBox(children=(HBox(children=(HTML(value='<b>Plot Configuration:</b>'), Checkbox(value=False, description='Sho…

# %%
# %perfmonitor_plot
# Out:
# BALI result_dirs to plot:['./bali_results/1564766/0', './bali_results/1564766/1']
# 2026-05-13 16:54:35,462 - INFO -
# BALI result_dirs to plot:['./bali_results/1564766/0', './bali_results/1564766/1']
# 2026-05-13 16:54:35,490 - INFO - cached segments: [{'model': 'facebook/opt-1.3b', 'framework': 'hf_accelerate', 'batch_size': 128, 'input_len': 32, 'output_len': 32, 'num_samples': 1024, 'iteration': '0', 'start_time': 712208.252209395, 'end_time': 712218.820281019, 'duration': 10.568071623914875, 'duration_text_gen': 7.492446960997768, 'start_text_gen': 712211.327834058, 'tokens_per_sec': 4198.891138472306, 'is_error': False, 'error_message': nan}, {'model': 'facebook/opt-1.3b', 'framework': 'hf_accelerate', 'batch_size': 256, 'input_len': 32, 'output_len': 32, 'num_samples': 1024, 'iteration': '0', 'start_time': 712219.118767953, 'end_time': 712226.576358345, 'duration': 7.4575903919758275, 'duration_text_gen': 5.88345515797846, 'start_text_gen': 712220.692903187, 'tokens_per_sec': 5298.409605432161, 'is_error': False, 'error_message': nan}, {'model': 'facebook/opt-1.3b', 'framework': 'hf_accelerate', 'batch_size': 128, 'input_len': 32, 'output_len': 32, 'num_samples': 1024, 'iteration': '0', 'start_time': 712244.575201766, 'end_time': 712253.322936819, 'duration': 8.747735053068027, 'duration_text_gen': 7.1638456711079925, 'start_text_gen': 712246.159091148, 'tokens_per_sec': 4387.032662157015, 'is_error': False, 'error_message': nan}, {'model': 'facebook/opt-1.3b', 'framework': 'hf_accelerate', 'batch_size': 256, 'input_len': 32, 'output_len': 32, 'num_samples': 1024, 'iteration': '0', 'start_time': 712253.613575761, 'end_time': 712261.109183811, 'duration': 7.495608050026931, 'duration_text_gen': 5.88195202301722, 'start_text_gen': 712255.227231788, 'tokens_per_sec': 5310.304365290123, 'is_error': False, 'error_message': nan}]
# <script>
# (function(){
#   if(typeof window.Plotly!=='undefined')return;
#   var s=document.createElement('script');
#   s.src='https://cdn.plot.ly/plotly-2.35.2.min.js';
#   s.charset='utf-8';
#   document.head.appendChild(s);
# })();
# </script>
# <style>
# /* ── Scoped container base ───────────────────────────────────────────────── */
# /* Token fallback chain: VS Code → JupyterLab → static light value */
# .jump-vis-container {
#   --bg:           var(--vscode-editor-background,     var(--jp-layout-color0,       #ffffff));
#   --text:         var(--vscode-editor-foreground,     var(--jp-content-font-color0, #111827));
#   --muted:        var(--vscode-descriptionForeground, var(--jp-content-font-color2, #4b5563));
#   --border:       var(--vscode-widget-border,         var(--jp-border-color1,       #e5e7eb));
#   --slider-track: #d1d5db;
#   --slider-range: #6b7280;
#   --slider-thumb: #374151;
#
#   box-sizing: border-box;
#   background: var(--bg);
#   color: var(--text);
#   font-family: ui-sans-serif, -apple-system, Segoe UI, Roboto, Ubuntu,
#                Cantarell, Noto Sans, Arial;
#   padding: 8px 4px 4px 4px;
# }
# .jump-vis-container *,
# .jump-vis-container *::before,
# .jump-vis-container *::after { box-sizing: border-box; }
#
# /* ── Toolbar ─────────────────────────────────────────────────────────────── */
# .jump-vis-toolbar {
#   display: flex;
#   flex-wrap: wrap;
#   align-items: center;
#   gap: 14px;
#   padding: 4px 0 10px 0;
#   border-bottom: 1px solid var(--border);
#   margin-bottom: 10px;
# }
#
# .jump-vis-logo img {
#   height: 28px;
#   width: auto;
#   vertical-align: middle;
# }
#
# .jump-vis-config-label {
#   font-weight: 600;
#   font-size: 13px;
#   color: var(--text);
#   white-space: nowrap;
# }
#
# /* ── Show-idle checkbox ──────────────────────────────────────────────────── */
# .jump-vis-ctrl-label {
#   display: inline-flex;
#   align-items: center;
#   gap: 6px;
#   color: var(--muted);
#   font-size: 13px;
#   cursor: pointer;
#   user-select: none;
#   white-space: nowrap;
# }
#
# .jump-vis-ctrl-label input[type="checkbox"] {
#   cursor: pointer;
#   accent-color: var(--slider-thumb);
#   width: 14px;
#   height: 14px;
# }
#
# /* Reuse the same .jump-vis-ctrl-label styling as the show-idle checkbox. */
#
# /* ── BALI colorbar scales ────────────────────────────────────────────────── */
# .jump-vis-bali-scales {
#   display: flex;
#   flex-wrap: wrap;
#   gap: 18px;
#   align-items: center;
#   padding: 4px 0 8px 0;
#   margin-bottom: 6px;
#   border-bottom: 1px dashed var(--border);
# }
#
# .jump-vis-bali-scale {
#   display: inline-flex;
#   align-items: center;
#   gap: 6px;
#   font-size: 12px;
#   color: var(--muted);
# }
#
# .jump-vis-bali-scale-label {
#   font-weight: 600;
#   color: var(--text);
# }
#
# .jump-vis-bali-scale-min,
# .jump-vis-bali-scale-max {
#   font-variant-numeric: tabular-nums;
#   min-width: 28px;
#   text-align: center;
# }
#
# .jump-vis-bali-scale-bar {
#   width: 160px;
#   height: 12px;
#   border: 1px solid var(--border);
#   border-radius: 2px;
# }
#
# /* Matches BaliResultsParser.colormap (blue_to_orange) */
# .jump-vis-bali-scale-bar--tokens {
#   background: linear-gradient(
#     to right,
#     #51829B 0%,
#     #9BB0C1 50%,
#     #F6995C 100%
#   );
# }
#
# /* Matches BaliResultsParser.colormap_energy (yellow_to_red) */
# .jump-vis-bali-scale-bar--energy {
#   background: linear-gradient(
#     to right,
#     #EADFB4 0%,
#     #F6995C 50%,
#     #874C62 100%
#   );
# }
#
# /* ── Cell-range dual-range slider ───────────────────────────────────────── */
# .jump-vis-range-wrap {
#   display: flex;
#   align-items: center;
#   gap: 8px;
#   flex-shrink: 0;
# }
#
# .jump-vis-range-label {
#   font-size: 12px;
#   color: var(--muted);
#   white-space: nowrap;
# }
#
# .jump-vis-range-label-value {
#   font-weight: 600;
#   color: var(--text);
# }
#
# /* Outer container for the two overlapping <input type="range"> */
# .jump-vis-dual-range {
#   position: relative;
#   width: 180px;
#   height: 20px;
#   flex-shrink: 0;
# }
#
# /* Both thumbs are stacked on the same track.
#    pointer-events: none on the input makes the track transparent;
#    pointer-events: all on the thumb pseudo-element restores only thumb hits. */
# .jump-vis-dual-range input[type="range"] {
#   position: absolute;
#   width: 100%;
#   height: 100%;
#   top: 0;
#   background: transparent;
#   pointer-events: none;
#   -webkit-appearance: none;
#   appearance: none;
#   outline: none;
#   margin: 0;
#   padding: 0;
# }
#
# /* Hide native track so only our custom track shows.
#    margin-top centres the 4 px track inside the 20 px input. */
# .jump-vis-dual-range input[type="range"]::-webkit-slider-runnable-track {
#   background: transparent;
#   height: 4px;
#   margin-top: 8px;   /* (20px input - 4px track) / 2 */
# }
# .jump-vis-dual-range input[type="range"]::-moz-range-track {
#   background: transparent;
#   height: 4px;
# }
#
# /* Thumb styling — pointer-events: all re-enables hit testing on the thumb only.
#    margin-top centres the 14 px thumb on the 4 px native track:
#    (4px - 14px) / 2 = -5px  */
# .jump-vis-dual-range input[type="range"]::-webkit-slider-thumb {
#   -webkit-appearance: none;
#   appearance: none;
#   pointer-events: all;
#   width: 14px;
#   height: 14px;
#   margin-top: -10px;
#   border-radius: 50%;
#   background: var(--slider-thumb);
#   cursor: pointer;
#   border: 2px solid var(--bg);
#   box-shadow: 0 0 0 1px var(--slider-thumb);
# }
# .jump-vis-dual-range input[type="range"]::-moz-range-thumb {
#   pointer-events: all;
#   width: 14px;
#   height: 14px;
#   border-radius: 50%;
#   background: var(--slider-thumb);
#   cursor: pointer;
#   border: 2px solid var(--bg);
#   box-shadow: 0 0 0 1px var(--slider-thumb);
# }
#
# /* Custom visible track drawn behind both thumbs */
# .jump-vis-dual-range-track {
#   position: absolute;
#   top: 50%;
#   transform: translateY(-50%);
#   left: 0;
#   right: 0;
#   height: 4px;
#   border-radius: 2px;
#   background: var(--slider-track);
#   pointer-events: none;
#   z-index: 0;
# }
#
# /* Highlighted fill segment between the two thumbs */
# .jump-vis-dual-range-fill {
#   position: absolute;
#   height: 100%;
#   border-radius: 2px;
#   background: var(--slider-range);
#   pointer-events: none;
# }
#
# /* ── Add Panel button ────────────────────────────────────────────────────── */
# .jump-vis-add-btn {
#   padding: 4px 12px;
#   border: 1px solid var(--border);
#   border-radius: 6px;
#   background: var(--bg);
#   color: var(--text);
#   font-size: 13px;
#   cursor: pointer;
#   white-space: nowrap;
# }
#
# .jump-vis-add-btn:disabled {
#   opacity: 0.4;
#   cursor: not-allowed;
# }
#
# .jump-vis-add-btn:not(:disabled):hover {
#   background: var(--border);
# }
#
# /* ── Panels grid ─────────────────────────────────────────────────────────── */
# .jump-vis-panels-wrap {
#   display: flex;
#   flex-direction: column;
#   gap: 12px;
# }
#
# .jump-vis-panel-row {
#   display: flex;
#   flex-wrap: wrap;
#   gap: 12px;
# }
#
# /* ── Individual panel ────────────────────────────────────────────────────── */
# .jump-vis-panel {
#   flex: 1 1 0;
#   min-width: 280px;
#   border: 1px solid var(--border);
#   border-radius: 8px;
#   padding: 8px 10px;
#   background: var(--bg);
# }
#
# /* ── Panel control row (metric / level dropdowns) ────────────────────────── */
# .jump-vis-ctrl-row {
#   display: flex;
#   flex-wrap: wrap;
#   gap: 8px;
#   margin-bottom: 6px;
#   align-items: center;
# }
#
# .jump-vis-ctrl-row label {
#   display: inline-flex;
#   align-items: center;
#   gap: 4px;
#   font-size: 12px;
#   color: var(--muted);
# }
#
# .jump-vis-ctrl-row select {
#   font-size: 12px;
#   padding: 2px 4px;
#   border: 1px solid var(--border);
#   border-radius: 4px;
#   background: var(--bg);
#   color: var(--text);
# }
#
# /* ── Plot area inside each panel ─────────────────────────────────────────── */
# .jump-vis-plot-area {
#   width: 100%;
#   min-height: 220px;
# }
#
# /* ── Status messages ─────────────────────────────────────────────────────── */
# .jump-vis-no-data {
#   color: var(--muted);
#   font-style: italic;
#   font-size: 13px;
#   padding: 20px 0;
# }
#
# .jump-vis-max-notice {
#   color: var(--muted);
#   font-size: 13px;
#   padding: 4px 0;
# }
#
# </style>
# <div id="jump-vis-8de78416" class="jump-vis-container">
#   <div class="jump-vis-toolbar">
#   <span class="jump-vis-logo">
#     <img src="data:image/png;base64,..." alt="JUmPER">
#   </span>
#   <span class="jump-vis-config-label">Plot Configuration:</span>
#   <label class="
