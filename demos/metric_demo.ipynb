# %%
# %reload_ext jumper_extension
# Out:
# [JUmPER]: NVIDIA drivers not available. NVIDIA GPU monitoring disabled.
# [JUmPER]: ADLXPybind not available. AMD GPU monitoring disabled.
# [JUmPER]: Perfmonitor extension loaded

# %% [markdown]
# # If using the wrapper kernel, execute the next cells

# %%
# %list_kernels

# %%
# %wrap_kernel python3

# %% [markdown]
# # Using the wrapper kernel or the plain extension, execute the next cells

# %%
# %perfmonitor_start 1
# Out:
# [JUmPER]: Performance monitoring started (PID: 80945, Interval: 1.0s)

# %%
# %perfmonitor_enable_perfreports
# Out:
# [JUmPER]: Performance monitoring already running
# [JUmPER]: Performance reports enabled for each cell (level: process, interval: 1.0, format: html)

# %%
# %perfmonitor_resources
# Out:
# [JUmPER]:
#   CPUs: 8
#     CPU affinity: [0, 1, 2, 3, 4, 5, 6, 7]
#   Memory: 23.13 GB
#   GPUs: 0

# %%
from random import random
import time
import multiprocessing
from multiprocessing import Pool
import sys

import numpy as np
import gc

import os
import time
import threading

import math

def throw_dart(iterations: int) -> int:
    hits = 0
    for i in range(iterations):
        x = random()
        y = random()
        if (x * x) + (y * y) <= 1:
            hits = hits + 1
    return hits


def compute_pi(iterations, process_count):
    pool = Pool(processes=process_count)
    trials_per_process = [int(iterations / process_count)] * process_count

    hits = pool.map(throw_dart, trials_per_process)
    pi = (sum(hits) * 4) / iterations

    print(f"Pi approximation: {pi}")
# Out:
# [JUmPER]: No performance data available or recorded cells are too short

# %%
# Cell 1: Utilizing all CPUs for 10**8 iterations
compute_pi(10**9, multiprocessing.cpu_count())
# Out:
# Pi approximation: 3.141544592
# <style>
# /* All variables and resets are scoped to the container to avoid leaking
#    into VS Code / JupyterLab dark-theme styles.
#    Fallback chain for each token:
#      1. VS Code Jupyter webview  (--vscode-*)
#      2. JupyterLab               (--jp-*)
#      3. Static light-theme value  */
# .jump-container {
#   --bg:     var(--vscode-editor-background,     var(--jp-layout-color0,       #ffffff));
#   --text:   var(--vscode-editor-foreground,     var(--jp-content-font-color0, #111827));
#   --muted:  var(--vscode-descriptionForeground, var(--jp-content-font-color2, #4b5563));
#   --border: var(--vscode-widget-border,         var(--jp-border-color1,       #e5e7eb));
#   --accent: #1f2937;
#   --tag-icon-size: 25px;
#   --max-content-width: 720px;
#
#   /* Scoped box-sizing reset */
#   box-sizing: border-box;
#
#   margin: 0;
#   padding: 0;
#   background: var(--bg);
#   font-family: ui-sans-serif, -apple-system, Segoe UI, Roboto, Ubuntu, Cantarell, Noto Sans, Arial, "Apple Color Emoji", "Segoe UI Emoji";
#   color: var(--text);
# }
# .jump-container *, .jump-container *::before, .jump-container *::after { box-sizing: border-box; }
#
# .jump-divider {
#   border: 0;
#   border-top: 1px solid var(--border);
#   margin: 0 0 8px 0;
#   max-width: var(--max-content-width, 720px);
#   width: 100%;
# }
#
# .jump-container {
#   background: var(--bg);
#   padding: 12px 4px 4px 4px;
#   position: relative; /* allow absolute children like taglist */
# }
#
# /* Common content width to align header subtitle with table right edge */
# .jump-content {
#   max-width: var(--max-content-width); /* matches .jump-table-wrap */
#   width: 100%;
#   margin: 0; /* keep left-aligned within container */
# }
#
# .jump-header {
#   display: flex;
#   flex-direction: row; /* title left, meta right */
#   flex-wrap: wrap;     /* allow header to grow in height on small widths */
#   justify-content: flex-start;
#   align-items: flex-start;
#   gap: 6px;
#   margin-bottom: 14px;
#   padding-right: 0;
#   position: relative;
# }
#
# .jump-right {
#   display: flex;
#   flex-direction: column;
#   align-items: flex-end;
#   margin-left: auto;
#   position: absolute;
#   right: 0;
#   top: 0;
# }
#
# .jump-title {
#   font-weight: 650;
#   letter-spacing: 0.3px;
#   color: var(--text);
# }
#
# .jump-subtitle {
#   color: var(--muted);
#   display: flex;
#   align-items: center;
#   gap: 8px;
#   align-self: flex-end; /* move subtitle to top-right */
#   text-align: right;
# }
#
# .jump-tags {
#   margin-top: 4px;
#   align-self: flex-end;
# }
#
# .jump-kv { display: inline-flex; gap: 6px; align-items: baseline; }
# .jump-k { color: var(--muted); font-size: 12px; text-transform: uppercase; letter-spacing: 0.08em; }
# .jump-v { color: var(--text); font-variant-numeric: tabular-nums; }
# .jump-sep { opacity: 0.35; }
#
# .jump-section-title {
#   color: var(--muted);
#   font-size: 12px;
#   text-transform: uppercase;
#   letter-spacing: 0.12em;
#   margin: 12px 0 8px;
# }
#
# .jump-tags .jump-section-title { display: none; }
#
# .jump-taglist {
#   /* Keep tag row in normal document flow and avoid overlapping table */
#   position: static !important;
#   display: flex;
#   flex-direction: row;
#   flex-wrap: wrap;
#   align-items: flex-start;
#   justify-content: flex-start;
#   overflow: visible;
#   gap: 8px;
#   margin: 8px 0 1px 0 !important;
#   width: 100%;             /* span same width as header/table */
#   padding-left: 0 !important;
#   padding-right: 12px;
#   padding-bottom: 1px !important;
#   z-index: 0;               /* sit below subsequent content if stacked */
# }
#
# .jump-tag {
#   display: inline-flex;
#   gap: 10px;
#   align-items: center;
#   border-radius: 10px;
#   padding: 1px 10px !important; /* enough room for dot and text */
#   line-height: 1.2;
#   min-height: 28px;
# }
# /* Higher specificity to override JupyterLab's span background reset */
# .jump-container .jump-tag {
#   background: var(--bg);
#   border: 1px solid var(--border);
#   color: var(--text);
# }
# /* Remove the colored dot before each tag; only SVG + name remain */
# .jump-tag::before { content: none; display: none; }
# .jump-tag-icon { opacity: 0.9; }
# .jump-tag-name { font-size: 13px; letter-spacing: 0.02em; }
#
# .jump-tag--small { padding: 4px 8px; }
# .jump-tag--small .jump-tag-name { font-size: 12px; }
#
# /* Tag theme classes: set color via CSS custom property */
# .jump-tag--cpu-bound      { --tag-color: #ef4444; } /* red */
# .jump-tag--memory-bound   { --tag-color: #3b82f6; } /* blue */
# .jump-tag--gpu-util-bound { --tag-color: #8b5cf6; } /* violet */
# .jump-tag--gpu-memory-bound { --tag-color: #14b8a6; } /* teal */
# .jump-tag--normal         { --tag-color: #22c55e; } /* green */
# .jump-tag--unknown        { --tag-color: #9ca3af; } /* gray */
# .jump-tag--gpu-allocated-but-not-used { --tag-color: #9ca3af; } /* gray */
#
# /* Icon placeholder: allows inlining SVG later via --tag-icon variable */
# .jump-tag-icon {
#   display: inline-flex;
#   width: var(--tag-icon-size, 20px);
#   height: var(--tag-icon-size, 20px);
#   align-items: center;
#   justify-content: center;
# }
# /* Render masked icon only when there is no inline SVG inside */
# .jump-tag-icon:empty::before {
#   content: "";
#   display: block;
#   width: var(--tag-icon-size, 20px);
#   height: var(--tag-icon-size, 20px);
#   /* If --tag-icon is provided as a URL to an SVG, mask it; otherwise stays empty */
#   background-color: currentColor;
#   -webkit-mask: var(--tag-icon) no-repeat center / contain;
#   mask: var(--tag-icon) no-repeat center / contain;
# }
# /* Ensure any inline SVG scales nicely inside the placeholder */
# .jump-tag-icon svg { display: block; width: var(--tag-icon-size, 20px); height: var(--tag-icon-size, 20px); }
#
# /* Ensure the metrics section starts on its own line in normal flow */
# .jump-metrics { display: block; clear: both; }
#
# /* Metrics table (left-aligned, constrained) */
# .jump-table-wrap {
#   max-width: 720px;
#   background: var(--bg);
#   margin-top: 4px;
#   position: relative; /* ensure it sits above tag row if ever stacked */
#   z-index: 1;
# }
#
# .jump-table {
#   width: 100%;
#   border-collapse: collapse;
#   font-variant-numeric: tabular-nums;
# }
#
# .jump-table thead th {
#   background: var(--bg);
#   color: var(--muted);
#   font-weight: 600;
#   text-align: left;
#   font-size: 12px;
#   letter-spacing: 0.06em;
#   text-transform: uppercase;
#   padding: 8px 8px;
# }
#
# .jump-table tbody td {
#   padding: 8px 8px;
# }
#
# .jump-col-metric {
#   color: var(--text);
#   font-weight: 500;
# }
#
# </style>
# <div class="jump-container">
#     <hr class="jump-divider" />
#     <div class="jump-content">
#       <header class="jump-header">
#         <div class="jump-title">JUmPER Performance Report</div>
#         <div class="jump-right">
#           <div class="jump-subtitle">
#             <span class="jump-kv">
#               <span class="jump-k">Duration</span>
#               <span class="jump-v">90.59s</span>
#             </span>
#             <span class="jump-sep">•</span>
#             <span class="jump-kv">
#               <span class="jump-k">Cells</span>
#               <span class="jump-v">1</span>
#             </span>
#           </div>
#         </div>
#       </header>
#
#       <div class="jump-taglist">
#
#           <span class="jump-tag jump-tag--cpu-bound">
#             <span class="jump-tag-icon" aria-hidden="true">
#
#
#                 <!-- CPU icon; color driven by --tag-color to match tag theme -->
#                 <svg width="16" height="16" viewBox="0 0 64 64" xmlns="http://www.w3.org/2000/svg" role="img" aria-label="CPU icon">
#                   <g fill="none" stroke="var(--tag-color, #6b7280)" stroke-width="2" stroke-linecap="round" stroke-linejoin="round">
#                     <rect x="16" y="16" width="32" height="32" rx="4"/>
#                     <rect x="24" y="24" width="16" height="16" rx="2"/>
#                     <line x1="24" y1="12" x2="24" y2="16"/>
#                     <line x1="32" y1="12" x2="32" y2="16"/>
#                     <line x1="40" y1="12" x2="40" y2="16"/>
#                     <line x1="24" y1="48" x2="24" y2="52"/>
#                     <line x1="32" y1="48" x2="32" y2="52"/>
#                     <line x1="40" y1="48" x2="40" y2="52"/>
#                     <line x1="12" y1="24" x2="16" y2="24"/>

# %%
# %perfmonitor_plot
# Out:
# <script>
# (function(){
#   if(typeof window.Plotly!=='undefined')return;
#   var s=document.createElement('script');
#   s.src='https://cdn.plot.ly/plotly-2.35.2.min.js';
#   s.charset='utf-8';
#   document.head.appendChild(s);
# })();
# </script>
# <style>
# /* ── Scoped container base ───────────────────────────────────────────────── */
# /* Token fallback chain: VS Code → JupyterLab → static light value */
# .jump-vis-container {
#   --bg:           var(--vscode-editor-background,     var(--jp-layout-color0,       #ffffff));
#   --text:         var(--vscode-editor-foreground,     var(--jp-content-font-color0, #111827));
#   --muted:        var(--vscode-descriptionForeground, var(--jp-content-font-color2, #4b5563));
#   --border:       var(--vscode-widget-border,         var(--jp-border-color1,       #e5e7eb));
#   --slider-track: #d1d5db;
#   --slider-range: #6b7280;
#   --slider-thumb: #374151;
#
#   box-sizing: border-box;
#   background: var(--bg);
#   color: var(--text);
#   font-family: ui-sans-serif, -apple-system, Segoe UI, Roboto, Ubuntu,
#                Cantarell, Noto Sans, Arial;
#   padding: 8px 4px 4px 4px;
# }
# .jump-vis-container *,
# .jump-vis-container *::before,
# .jump-vis-container *::after { box-sizing: border-box; }
#
# /* ── Toolbar ─────────────────────────────────────────────────────────────── */
# .jump-vis-toolbar {
#   display: flex;
#   flex-wrap: wrap;
#   align-items: center;
#   gap: 14px;
#   padding: 4px 0 10px 0;
#   border-bottom: 1px solid var(--border);
#   margin-bottom: 10px;
# }
#
# .jump-vis-logo img {
#   height: 28px;
#   width: auto;
#   vertical-align: middle;
# }
#
# .jump-vis-config-label {
#   font-weight: 600;
#   font-size: 13px;
#   color: var(--text);
#   white-space: nowrap;
# }
#
# /* ── Show-idle checkbox ──────────────────────────────────────────────────── */
# .jump-vis-ctrl-label {
#   display: inline-flex;
#   align-items: center;
#   gap: 6px;
#   color: var(--muted);
#   font-size: 13px;
#   cursor: pointer;
#   user-select: none;
#   white-space: nowrap;
# }
#
# .jump-vis-ctrl-label input[type="checkbox"] {
#   cursor: pointer;
#   accent-color: var(--slider-thumb);
#   width: 14px;
#   height: 14px;
# }
#
# /* ── Cell-range dual-range slider ───────────────────────────────────────── */
# .jump-vis-range-wrap {
#   display: flex;
#   align-items: center;
#   gap: 8px;
#   flex-shrink: 0;
# }
#
# .jump-vis-range-label {
#   font-size: 12px;
#   color: var(--muted);
#   white-space: nowrap;
# }
#
# .jump-vis-range-label-value {
#   font-weight: 600;
#   color: var(--text);
# }
#
# /* Outer container for the two overlapping <input type="range"> */
# .jump-vis-dual-range {
#   position: relative;
#   width: 180px;
#   height: 20px;
#   flex-shrink: 0;
# }
#
# /* Both thumbs are stacked on the same track.
#    pointer-events: none on the input makes the track transparent;
#    pointer-events: all on the thumb pseudo-element restores only thumb hits. */
# .jump-vis-dual-range input[type="range"] {
#   position: absolute;
#   width: 100%;
#   height: 100%;
#   top: 0;
#   background: transparent;
#   pointer-events: none;
#   -webkit-appearance: none;
#   appearance: none;
#   outline: none;
#   margin: 0;
#   padding: 0;
# }
#
# /* Hide native track so only our custom track shows.
#    margin-top centres the 4 px track inside the 20 px input. */
# .jump-vis-dual-range input[type="range"]::-webkit-slider-runnable-track {
#   background: transparent;
#   height: 4px;
#   margin-top: 8px;   /* (20px input - 4px track) / 2 */
# }
# .jump-vis-dual-range input[type="range"]::-moz-range-track {
#   background: transparent;
#   height: 4px;
# }
#
# /* Thumb styling — pointer-events: all re-enables hit testing on the thumb only.
#    margin-top centres the 14 px thumb on the 4 px native track:
#    (4px - 14px) / 2 = -5px  */
# .jump-vis-dual-range input[type="range"]::-webkit-slider-thumb {
#   -webkit-appearance: none;
#   appearance: none;
#   pointer-events: all;
#   width: 14px;
#   height: 14px;
#   margin-top: -10px;
#   border-radius: 50%;
#   background: var(--slider-thumb);
#   cursor: pointer;
#   border: 2px solid var(--bg);
#   box-shadow: 0 0 0 1px var(--slider-thumb);
# }
# .jump-vis-dual-range input[type="range"]::-moz-range-thumb {
#   pointer-events: all;
#   width: 14px;
#   height: 14px;
#   border-radius: 50%;
#   background: var(--slider-thumb);
#   cursor: pointer;
#   border: 2px solid var(--bg);
#   box-shadow: 0 0 0 1px var(--slider-thumb);
# }
#
# /* Custom visible track drawn behind both thumbs */
# .jump-vis-dual-range-track {
#   position: absolute;
#   top: 50%;
#   transform: translateY(-50%);
#   left: 0;
#   right: 0;
#   height: 4px;
#   border-radius: 2px;
#   background: var(--slider-track);
#   pointer-events: none;
#   z-index: 0;
# }
#
# /* Highlighted fill segment between the two thumbs */
# .jump-vis-dual-range-fill {
#   position: absolute;
#   height: 100%;
#   border-radius: 2px;
#   background: var(--slider-range);
#   pointer-events: none;
# }
#
# /* ── Add Panel button ────────────────────────────────────────────────────── */
# .jump-vis-add-btn {
#   padding: 4px 12px;
#   border: 1px solid var(--border);
#   border-radius: 6px;
#   background: var(--bg);
#   color: var(--text);
#   font-size: 13px;
#   cursor: pointer;
#   white-space: nowrap;
# }
#
# .jump-vis-add-btn:disabled {
#   opacity: 0.4;
#   cursor: not-allowed;
# }
#
# .jump-vis-add-btn:not(:disabled):hover {
#   background: var(--border);
# }
#
# /* ── Panels grid ─────────────────────────────────────────────────────────── */
# .jump-vis-panels-wrap {
#   display: flex;
#   flex-direction: column;
#   gap: 12px;
# }
#
# .jump-vis-panel-row {
#   display: flex;
#   flex-wrap: wrap;
#   gap: 12px;
# }
#
# /* ── Individual panel ────────────────────────────────────────────────────── */
# .jump-vis-panel {
#   flex: 1 1 0;
#   min-width: 280px;
#   border: 1px solid var(--border);
#   border-radius: 8px;
#   padding: 8px 10px;
#   background: var(--bg);
# }
#
# /* ── Panel control row (metric / level dropdowns) ────────────────────────── */
# .jump-vis-ctrl-row {
#   display: flex;
#   flex-wrap: wrap;
#   gap: 8px;
#   margin-bottom: 6px;
#   align-items: center;
# }
#
# .jump-vis-ctrl-row label {
#   display: inline-flex;
#   align-items: center;
#   gap: 4px;
#   font-size: 12px;
#   color: var(--muted);
# }
#
# .jump-vis-ctrl-row select {
#   font-size: 12px;
#   padding: 2px 4px;
#   border: 1px solid var(--border);
#   border-radius: 4px;
#   background: var(--bg);
#   color: var(--text);
# }
#
# /* ── Plot area inside each panel ─────────────────────────────────────────── */
# .jump-vis-plot-area {
#   width: 100%;
#   min-height: 220px;
# }
#
# /* ── Status messages ─────────────────────────────────────────────────────── */
# .jump-vis-no-data {
#   color: var(--muted);
#   font-style: italic;
#   font-size: 13px;
#   padding: 20px 0;
# }
#
# .jump-vis-max-notice {
#   color: var(--muted);
#   font-size: 13px;
#   padding: 4px 0;
# }
#
# </style>
# <div id="jump-vis-9d6538a1" class="jump-vis-container">
#   <div class="jump-vis-toolbar">
#   <span class="jump-vis-logo">
#     <img src="data:image/png;base64,..." alt="JUmPER">
#   </span>
#   <span class="jump-vis-config-label">Plot Configuration:</span>
#   <label class="jump-vis-ctrl-label">
#   <input type="checkbox"
#          id="jump-vis-9d6538a1-show-idle"
#          >
#   Show idle periods
# </label>
#   <div class="jump-vis-range-wrap">
#   <span class="jump-vis-range-label">
#     Cell range:&nbsp;<span class="jump-vis-range-label-value"
#                            id="jump-vis-9d6538a1-range-val">6–6</span>
#   </span>
#   <div class="jump-vis-dual-range">
#     <div class="jump-vis-dual-range-track">
#       <div class="jump-vis-dual-range-fill" id="jump-vis-9d6538a1-range-fill"></div>
#     </div>
#     <input type="range"
#            id="jump-vis-9d6538a1-range-min"
#            min="0" max="6"
#            value="6" step="1">
#     <input type="range"
#            id="jump-vis-9d6538a1-range-max"
#            min="0" max="6"
#            value="6" step="1">
#   </div>
# </div>
#   <button class="jump-vis-add-btn" id="jump-vis-9d6538a1-add-btn">+ Add Panel</button>
# </div>
#   <div class="jump-vis-panels-wrap" id="jump-vis-9d6538a1-panels"></div>
# </div>
# <script>
# var CID      = "jump-vis-9d6538a1";
# var FIGS     = {"cpu_summary": {"user": {"false": {"data": [{"line": {"color": "blue", "dash": "dot", "width": 2}, "mode": "lines", "name": "Min", "opacity": 0.35, "x": [0.05897503899905132,

# %%
# %perfmonitor_stop
# Out:
# [JUmPER]: Performance monitoring stopped (ran for 144.06 seconds)
# [JUmPER]: Missed measurements: ( 0.00)

# %%
# %perfmonitor_plot --live --level process
# Out:
# <div style="display:flex;align-items:center;justify-content:space-between;
#             flex-wrap:wrap;margin-bottom:8px">
#   <b>Live Performance Monitor</b>
#   <span>
#     <span id="jumper-status-f23b444e"
#           style="color:green;font-weight:bold">● Live</span>
#     <span style="color:#666;margin-left:8px">
#       window 120s / update 2.0s
#     </span>
#   </span>
#   <img src="data:image/png;base64,..." alt="JUmPER"
#        style="height:auto;width:100px" onerror="this.style.display='none'">
# </div>
# <p style="color:#666;font-size:0.9em">
#   Panels: CPU Utilization Summary, Memory Usage
#   (level: process).
# </p>
# <div style='display:grid;grid-template-columns:repeat(2,1fr);gap:8px'><div style='padding:4px'><div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.4.0.min.js" integrity="sha256-KEmPoupLpFyGMyGAiOsiNDbKDKAvxXAn/W+oQa0ZAfk=" crossorigin="anonymous"></script>                <div id="8981341b-ed8c-4d46-bb1e-931e963417c5" class="plotly-graph-div" style="height:315px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8981341b-ed8c-4d46-bb1e-931e963417c5")) {                    Plotly.newPlot(                        "8981341b-ed8c-4d46-bb1e-931e963417c5",                        [{"line":{"color":"blue","dash":"dot","width":2},"mode":"lines","name":"Min","opacity":0.35,"x":{"dtype":"f8","bdata":"AHBd0vopI0AAIA7QhTIlQADAIKW2mChAAEAUig+lK0AAANWQz00xQACIj3ENIzNAANBLYeWSNEAAIJqRWOw1QAAISFJXPzdAALCM3aOkOEAA4Llj1rU6QAAwC\u002fjFvDxAAJhgo\...\u002fmVkAAjJ+JWidXQACULjoPZ1dAANIvrKOwV0AAqBgfWgNYQAAWwRh0VlhAAKSf2FmZWEAAsmMo6eJYQAAk1Wq0KVlAAFC6hVKAWUAAch17J9ZZQADwVnz0LFpAAATS2mF3WkAAimGlZ8ZaQAAMC4tdBltAAPh\u002fSj9GW0AAuqVtzYVbQAAI57bRxltAAFaMrsMFXEAAqjyJAUZcQACmtIwhhlxAAECUpDXGXEAA7pTj9QZdQAAQembkRV1AADiq3\u002fSGXUAAfiyd38VdQACkqj70Bl5AAKgPqOdFXkAA+ObP6IVeQABUDUnNxV5AAB4pGykGX0AALjjF+0VfQAAUnLolhl9AACqAlB7HX0A="},"y":{"dtype":"f8","bdata":"...\"},"type":"scatter"},{"line":{"color":"blue","dash":"solid","width":2},"mode":"lines","name":"Average","opacity":1.0,"x":{"dtype":"f8","bdata":"AHBd0vopI0AAIA7QhTIlQADAIKW2mChAAEAUig+lK0AAANWQz00xQACIj3ENIzNAANBLYeWSNEAAIJqRWOw1QAAISFJXPzdAALCM3aOkOEAA4Llj1rU6QAAwC\u002fjFvDxAAJhgo\...\u002fmVkAAjJ+JWidXQACULjoPZ1dAANIvrKOwV0AAqBgfWgNYQAAWwRh0VlhAAKSf2FmZWEAAsmMo6eJYQAAk1Wq0KVlAAFC6hVKAWUAAch17J9ZZQADwVnz0LFpAAATS2mF3WkAAimGlZ8ZaQAAMC4tdBltAAPh\u002fSj9GW0AAuqVtzYVbQAAI57bRxltAAFaMrsMFXEAAqjyJAUZcQACmtIwhhlxAAECUpDXGXEAA7pTj9QZdQAAQembkRV1AADiq3\u002fSGXUAAfiyd38VdQACkqj70Bl5AAKgPqOdFXkAA+ObP6IVeQABUDUnNxV5AAB4pGykGX0AALjjF+0VfQAAUnLolhl9AACqAlB7HX0A="},"y":{"dtype":"f8","bdata":"...\"},"type":"scatter"},{"line":{"color":"blue","dash":"dash","width":2},"mode":"lines","name":"Max","opacity":0.35,"x":{"dtype":"f8","bdata":"AHBd0vopI0AAIA7QhTIlQADAIKW2mChAAEAUig+lK0AAANWQz00xQACIj3ENIzNAANBLYeWSNEAAIJqRWOw1QAAISFJXPzdAALCM3aOkOEAA4Llj1rU6QAAwC\u002fjFvDxAAJhgo\...\u002fmVkAAjJ+JWidXQACULjoPZ1dAANIvrKOwV0AAqBgfWgNYQAAWwRh0VlhAAKSf2FmZWEAAsmMo6eJYQAAk1Wq0KVlAAFC6hVKAWUAAch17J9ZZQADwVnz0LFpAAATS2mF3WkAAimGlZ8ZaQAAMC4tdBltAAPh\u002fSj9GW0AAuqVtzYVbQAAI57bRxltAAFaMrsMFXEAAqjyJAUZcQACmtIwhhlxAAECUpDXGXEAA7pTj9QZdQAAQembkRV1AADiq3\u002fSGXUAAfiyd38VdQACkqj70Bl5AAKgPqOdFXkAA+ObP6IVeQABUDUnNxV5AAB4pGykGX0AALjjF+0VfQAAUnLolhl9AACqAlB7HX0A="},"y":{"dtype":"f8","bdata":"...\"},"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color ...
# Live plotting started (update every 2.0s, window 120s). Interrupt kernel or stop monitor to end.

# %%
# Cell 2: Utilizing half of the CPUs for 10**8 iterations
compute_pi(10**8, multiprocessing.cpu_count()//2)
# Out:
# Pi approximation: 3.14149368
# <style>
# /* All variables and resets are scoped to the container to avoid leaking
#    into VS Code / JupyterLab dark-theme styles.
#    Fallback chain for each token:
#      1. VS Code Jupyter webview  (--vscode-*)
#      2. JupyterLab               (--jp-*)
#      3. Static light-theme value  */
# .jump-container {
#   --bg:     var(--vscode-editor-background,     var(--jp-layout-color0,       #ffffff));
#   --text:   var(--vscode-editor-foreground,     var(--jp-content-font-color0, #111827));
#   --muted:  var(--vscode-descriptionForeground, var(--jp-content-font-color2, #4b5563));
#   --border: var(--vscode-widget-border,         var(--jp-border-color1,       #e5e7eb));
#   --accent: #1f2937;
#   --tag-icon-size: 25px;
#   --max-content-width: 720px;
#
#   /* Scoped box-sizing reset */
#   box-sizing: border-box;
#
#   margin: 0;
#   padding: 0;
#   background: var(--bg);
#   font-family: ui-sans-serif, -apple-system, Segoe UI, Roboto, Ubuntu, Cantarell, Noto Sans, Arial, "Apple Color Emoji", "Segoe UI Emoji";
#   color: var(--text);
# }
# .jump-container *, .jump-container *::before, .jump-container *::after { box-sizing: border-box; }
#
# .jump-divider {
#   border: 0;
#   border-top: 1px solid var(--border);
#   margin: 0 0 8px 0;
#   max-width: var(--max-content-width, 720px);
#   width: 100%;
# }
#
# .jump-container {
#   background: var(--bg);
#   padding: 12px 4px 4px 4px;
#   position: relative; /* allow absolute children like taglist */
# }
#
# /* Common content width to align header subtitle with table right edge */
# .jump-content {
#   max-width: var(--max-content-width); /* matches .jump-table-wrap */
#   width: 100%;
#   margin: 0; /* keep left-aligned within container */
# }
#
# .jump-header {
#   display: flex;
#   flex-direction: row; /* title left, meta right */
#   flex-wrap: wrap;     /* allow header to grow in height on small widths */
#   justify-content: flex-start;
#   align-items: flex-start;
#   gap: 6px;
#   margin-bottom: 14px;
#   padding-right: 0;
#   position: relative;
# }
#
# .jump-right {
#   display: flex;
#   flex-direction: column;
#   align-items: flex-end;
#   margin-left: auto;
#   position: absolute;
#   right: 0;
#   top: 0;
# }
#
# .jump-title {
#   font-weight: 650;
#   letter-spacing: 0.3px;
#   color: var(--text);
# }
#
# .jump-subtitle {
#   color: var(--muted);
#   display: flex;
#   align-items: center;
#   gap: 8px;
#   align-self: flex-end; /* move subtitle to top-right */
#   text-align: right;
# }
#
# .jump-tags {
#   margin-top: 4px;
#   align-self: flex-end;
# }
#
# .jump-kv { display: inline-flex; gap: 6px; align-items: baseline; }
# .jump-k { color: var(--muted); font-size: 12px; text-transform: uppercase; letter-spacing: 0.08em; }
# .jump-v { color: var(--text); font-variant-numeric: tabular-nums; }
# .jump-sep { opacity: 0.35; }
#
# .jump-section-title {
#   color: var(--muted);
#   font-size: 12px;
#   text-transform: uppercase;
#   letter-spacing: 0.12em;
#   margin: 12px 0 8px;
# }
#
# .jump-tags .jump-section-title { display: none; }
#
# .jump-taglist {
#   /* Keep tag row in normal document flow and avoid overlapping table */
#   position: static !important;
#   display: flex;
#   flex-direction: row;
#   flex-wrap: wrap;
#   align-items: flex-start;
#   justify-content: flex-start;
#   overflow: visible;
#   gap: 8px;
#   margin: 8px 0 1px 0 !important;
#   width: 100%;             /* span same width as header/table */
#   padding-left: 0 !important;
#   padding-right: 12px;
#   padding-bottom: 1px !important;
#   z-index: 0;               /* sit below subsequent content if stacked */
# }
#
# .jump-tag {
#   display: inline-flex;
#   gap: 10px;
#   align-items: center;
#   border-radius: 10px;
#   padding: 1px 10px !important; /* enough room for dot and text */
#   line-height: 1.2;
#   min-height: 28px;
# }
# /* Higher specificity to override JupyterLab's span background reset */
# .jump-container .jump-tag {
#   background: var(--bg);
#   border: 1px solid var(--border);
#   color: var(--text);
# }
# /* Remove the colored dot before each tag; only SVG + name remain */
# .jump-tag::before { content: none; display: none; }
# .jump-tag-icon { opacity: 0.9; }
# .jump-tag-name { font-size: 13px; letter-spacing: 0.02em; }
#
# .jump-tag--small { padding: 4px 8px; }
# .jump-tag--small .jump-tag-name { font-size: 12px; }
#
# /* Tag theme classes: set color via CSS custom property */
# .jump-tag--cpu-bound      { --tag-color: #ef4444; } /* red */
# .jump-tag--memory-bound   { --tag-color: #3b82f6; } /* blue */
# .jump-tag--gpu-util-bound { --tag-color: #8b5cf6; } /* violet */
# .jump-tag--gpu-memory-bound { --tag-color: #14b8a6; } /* teal */
# .jump-tag--normal         { --tag-color: #22c55e; } /* green */
# .jump-tag--unknown        { --tag-color: #9ca3af; } /* gray */
# .jump-tag--gpu-allocated-but-not-used { --tag-color: #9ca3af; } /* gray */
#
# /* Icon placeholder: allows inlining SVG later via --tag-icon variable */
# .jump-tag-icon {
#   display: inline-flex;
#   width: var(--tag-icon-size, 20px);
#   height: var(--tag-icon-size, 20px);
#   align-items: center;
#   justify-content: center;
# }
# /* Render masked icon only when there is no inline SVG inside */
# .jump-tag-icon:empty::before {
#   content: "";
#   display: block;
#   width: var(--tag-icon-size, 20px);
#   height: var(--tag-icon-size, 20px);
#   /* If --tag-icon is provided as a URL to an SVG, mask it; otherwise stays empty */
#   background-color: currentColor;
#   -webkit-mask: var(--tag-icon) no-repeat center / contain;
#   mask: var(--tag-icon) no-repeat center / contain;
# }
# /* Ensure any inline SVG scales nicely inside the placeholder */
# .jump-tag-icon svg { display: block; width: var(--tag-icon-size, 20px); height: var(--tag-icon-size, 20px); }
#
# /* Ensure the metrics section starts on its own line in normal flow */
# .jump-metrics { display: block; clear: both; }
#
# /* Metrics table (left-aligned, constrained) */
# .jump-table-wrap {
#   max-width: 720px;
#   background: var(--bg);
#   margin-top: 4px;
#   position: relative; /* ensure it sits above tag row if ever stacked */
#   z-index: 1;
# }
#
# .jump-table {
#   width: 100%;
#   border-collapse: collapse;
#   font-variant-numeric: tabular-nums;
# }
#
# .jump-table thead th {
#   background: var(--bg);
#   color: var(--muted);
#   font-weight: 600;
#   text-align: left;
#   font-size: 12px;
#   letter-spacing: 0.06em;
#   text-transform: uppercase;
#   padding: 8px 8px;
# }
#
# .jump-table tbody td {
#   padding: 8px 8px;
# }
#
# .jump-col-metric {
#   color: var(--text);
#   font-weight: 500;
# }
#
# </style>
# <div class="jump-container">
#     <hr class="jump-divider" />
#     <div class="jump-content">
#       <header class="jump-header">
#         <div class="jump-title">JUmPER Performance Report</div>
#         <div class="jump-right">
#           <div class="jump-subtitle">
#             <span class="jump-kv">
#               <span class="jump-k">Duration</span>
#               <span class="jump-v">14.36s</span>
#             </span>
#             <span class="jump-sep">•</span>
#             <span class="jump-kv">
#               <span class="jump-k">Cells</span>
#               <span class="jump-v">1</span>
#             </span>
#           </div>
#         </div>
#       </header>
#
#       <div class="jump-taglist">
#
#       </div>
#
#       <section class="jump-metrics">
#         <div class="jump-table-wrap">
#           <table class="jump-table" role="grid">
#             <thead>
#               <tr>
#                 <th>Metric</th>
#                 <th>AVG</th>
#                 <th>MIN</th>
#                 <th>MAX</th>
#                 <th>Total/Limit</th>
#               </tr>
#             </thead>
#             <tbody>
#
#                 <tr>
#                   <td class="jump-col-metric">CPU Util (Across 8 CPUs)</td>
#                   <td>54.87</td>
#                   <td>18.14</td>
#                   <td>64.38</td>
#                   <td>-</td>
#                 </tr>
#
#                 <tr>
#                   <td class="jump-col-metric">Memory (GB)</td>
#                   <td>0.18</td>
#                   <td>0.16</td>
#                   <td>0.19</td>
#                   <td>23.13</td>
#                 </tr>
#
#             </tbody>
#           </table>
#         </div>
#       </section>
#     </div>
#   </div>

# %%
# %perfmonitor_plot

# %%
# Cell 3: Filling 2.5Gb of main memory
def fill_memory_2_5gb():
    """Fill 2.5GB of main memory"""
    print("Filling 2.5GB of main memory...")
    
    # Calculate number of elements for 2.5GB (assuming float64 = 8 bytes each)
    gb_size = 2.5 * 1024 * 1024 * 1024  # 2.5 GB in bytes
    num_elements = int(gb_size / 8)  # 8 bytes per float64 element
    
    print(f"Allocating {num_elements} float64 elements (~{2.5:.2f} GB)")
    
    # Create large arrays
    arrays = []
    try:
        # Create multiple arrays to avoid memory fragmentation issues
        for i in range(10):
            arr = np.ones(num_elements // 10, dtype=np.float64)
            arrays.append(arr)
            print(f"Created array {i+1}")
        
        # Force garbage collection to ensure memory is allocated
        gc.collect()
        
        print("2.5GB memory allocation completed")
        return arrays
        
    except MemoryError:
        print("Memory allocation failed!")
        return []

# Fill memory
allocated_arrays = fill_memory_2_5gb()
time.sleep(5)

# %%
# %perfmonitor_plot

# %%
# Write 1GB to disk in 10 seconds, force flush, wait 10sec, read back in 10 seconds
def write_and_read_1gb_forced():
    filename = "large_data_forced.bin"
    data_size = 1024 * 1024 * 1024  # 1GB in bytes
    chunk_size = 1024 * 1024  # 1MB chunks
    
    print("Starting 1GB write operation...")
    
    # Calculate write rate: 1GB in 10 seconds = 100MB/s
    target_rate_mb_per_sec = 100  # 100 MB/s
    target_time_per_chunk = 1.0 / target_rate_mb_per_sec  # 0.01 seconds per chunk
    
    start_time = time.perf_counter()
    written_bytes = 0
    chunk_count = 0
    
    # Write data with forced flushing
    with open(filename, 'wb') as f:
        f.flush()  # Ensure file is opened properly
        
        while written_bytes < data_size:
            # Create chunk of random data
            chunk = os.urandom(chunk_size)
            
            # Write chunk
            f.write(chunk)
            written_bytes += len(chunk)
            chunk_count += 1
            
            # Force write to disk immediately
            f.flush()
            os.fsync(f.fileno())
            
            # Calculate progress
            elapsed_time = time.perf_counter() - start_time
            if elapsed_time > 0:
                current_speed = written_bytes / (1024 * 1024) / elapsed_time  # MB/s
                print(f"Writing: {written_bytes / (1024**3):.2f} GB ({chunk_count} chunks), "
                      f"Speed: {current_speed:.2f} MB/s", end='\r')
            
            # Sleep to maintain 100MB/s rate (10ms per chunk)
            time.sleep(target_time_per_chunk)
    
    print(f"\nWritten {os.path.getsize(filename) / (1024**3):.2f} GB to disk")
    
    # Force OS to flush all buffers
    print("Forcing OS to flush all buffers...")
    os.sync()
    
    # Wait 10 seconds
    print("Waiting 10 seconds...")
    time.sleep(10)
    
    # Read data back with forced cache bypass
    print("Reading 1GB data back (forced cache bypass)...")
    start_time = time.perf_counter()
    read_bytes = 0
    read_chunk_count = 0
    
    # Method 1: Read with forced cache invalidation using posix_fadvise
    try:
        with open(filename, 'rb') as f:
            while read_bytes < data_size:
                # Read chunk
                chunk = f.read(chunk_size)
                if not chunk:
                    break
                    
                read_bytes += len(chunk)
                read_chunk_count += 1
                
                # Force OS to read from disk, not cache
                # This is the closest we can get to bypassing cache
                try:
                    os.posix_fadvise(f.fileno(), 0, 0, os.POSIX_FADV_DONTNEED)
                except:
                    # POSIX_FADV_DONTNEED not available on all systems
                    pass
                
                # Calculate progress
                elapsed_time = time.perf_counter() - start_time
                if elapsed_time > 0:
                    current_speed = read_bytes / (1024 * 1024) / elapsed_time  # MB/s
                    print(f"Reading: {read_bytes / (1024**3):.2f} GB ({read_chunk_count} chunks), "
                          f"Speed: {current_speed:.2f} MB/s", end='\r')
                
                # Sleep to maintain 100MB/s rate
                time.sleep(target_time_per_chunk)
                
    except Exception as e:
        print(f"Error during read: {e}")
        # Fallback: simple read without cache manipulation
        with open(filename, 'rb') as f:
            while read_bytes < data_size:
                chunk = f.read(chunk_size)
                if not chunk:
                    break
                read_bytes += len(chunk)
                read_chunk_count += 1
                
                # Calculate progress
                elapsed_time = time.perf_counter() - start_time
                if elapsed_time > 0:
                    current_speed = read_bytes / (1024 * 1024) / elapsed_time  # MB/s
                    print(f"Reading: {read_bytes / (1024**3):.2f} GB ({read_chunk_count} chunks), "
                          f"Speed: {current_speed:.2f} MB/s", end='\r')
                
                # Sleep to maintain 100MB/s rate
                time.sleep(target_time_per_chunk)
    
    print(f"\nRead {read_bytes / (1024**3):.2f} GB from disk")
    
    # Force OS to flush after reading
    print("Forcing OS to flush after reading...")
    os.sync()
    
    # Clean up
    os.remove(filename)
    print("1GB forced write/read operation completed")

# Execute the forced write/read operation
write_and_read_1gb_forced()

# %%
# %perfmonitor_plot

# %%
# Cell 6: CUDA Memory Operations (if CUDA available)
try:
    import torch
    
    def cuda_memory_operations():
        """Fill 2GB of CUDA memory, wait 10sec, then empty it"""
        if not torch.cuda.is_available():
            print("CUDA not available, skipping CUDA memory operations")
            return
            
        print("CUDA available, performing memory operations...")
        device = torch.device('cuda')
        
        # Calculate number of elements for 2GB (assuming float32 = 4 bytes each)
        gb_size = 2 * 1024 * 1024 * 1024  # 2 GB in bytes
        num_elements = int(gb_size / 4)  # 4 bytes per float32 element
        
        print(f"Allocating 2GB of CUDA memory ({num_elements} elements)")
        
        # Allocate memory on GPU
        tensor = torch.randn(num_elements, dtype=torch.float32, device=device)
        print(f"Allocated tensor size: {tensor.numel() * 4 / (1024**3):.2f} GB")
        
        # Wait 10 seconds
        print("Waiting 10 seconds...")
        time.sleep(10)
        
        # Free memory
        del tensor
        torch.cuda.empty_cache()
        print("CUDA memory freed")
        
        print("CUDA memory operations completed")
    
    # Execute CUDA memory operations
    cuda_memory_operations()
    
except ImportError:
    print("PyTorch not installed, skipping CUDA operations")
except Exception as e:
    print(f"CUDA operation error: {e}")

# %%
# %perfmonitor_plot

# %%
# Cell 7: CUDA Heavy Computation (if CUDA available)
try:
    import torch
    
    def cuda_heavy_computation():
        """Perform heavy computation on CUDA device for 20 seconds"""
        if not torch.cuda.is_available():
            print("CUDA not available, skipping CUDA heavy computation")
            return
            
        print("CUDA available, performing heavy computation...")
        device = torch.device('cuda')
        
        # Create large tensors for computation
        size = 10000  # Size of square matrices
        iterations = 0
        
        print(f"Starting heavy computation on CUDA for 20 seconds...")
        start_time = time.perf_counter()
        
        # Continue computation until 20 seconds have passed
        while time.perf_counter() - start_time < 20:
            # Create random matrices
            a = torch.randn(size, size, dtype=torch.float32, device=device)
            b = torch.randn(size, size, dtype=torch.float32, device=device)
            
            # Matrix multiplication (heavy operation)
            c = torch.matmul(a, b)
            
            # Additional computation to increase workload
            d = torch.sin(c) + torch.cos(c)
            
            # More operations to keep GPU busy
            e = torch.exp(d) * torch.log(d + 1e-8)
            
            # Increase iteration count
            iterations += 1
            
            # Clear cache periodically to prevent memory issues
            if iterations % 10 == 0:
                torch.cuda.empty_cache()
        
        print(f"Heavy computation completed in 20 seconds with {iterations} iterations")
        print("CUDA heavy computation completed")
    
    # Execute CUDA heavy computation
    cuda_heavy_computation()
    
except ImportError:
    print("PyTorch not installed, skipping CUDA heavy computation")
except Exception as e:
    print(f"CUDA heavy computation error: {e}")

# %%
# %perfmonitor_plot
